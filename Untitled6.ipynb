# %% [markdown]
# <a href="https://colab.research.google.com/github/ADARSHPHULARE/decision-tree/blob/main/Untitled6.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np

identity_matrix = np.eye(5)
print(identity_matrix)

# %%
print("\n2) Random marks for 10 students in 3 subjects + Average")
marks = np.random.randint(0, 101, (10, 3))       # random 0–100
average_per_student = marks.mean(axis=1)
print("Marks:\n", marks)
print("Average per student:\n", average_per_student)

# %%
print("\n3) Slice elements 2nd to 4th from [10,20,30,40,50]")
arr = np.array([10, 20, 30, 40, 50])
result_slice = arr[1:4]
print(result_slice)

# %%
print("\n4) Reshape 0–11 into 3x4 table and flatten back")
arr2 = np.arange(12)
reshaped = arr2.reshape(3, 4)
flattened = reshaped.flatten()
print("Reshaped:\n", reshaped)
print("Flattened:\n", flattened)

# %%
print("\n5) Add 10 marks grace using broadcasting")
marks_arr = np.array([50, 60, 70, 80])
grace = marks_arr + 10
print(grace)
